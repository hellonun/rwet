# %%
import random
import textwrap

nouns = [
'reason',
'obsession',
'foraging',
'heart',
'restaurant',
'foraging',
'prepackaged grocery store food',
'life',
'interface',
'Her',
'technology',
'culinary',
'common sense',
'cheese',
'confusion',
'disgust',
'smells',
'smell',
'light']

verbs = [
'get',
'explain',
'overwhelmed'
]

adjectives =[
'religious',
'scientific',
'natural',
'effortless',
'interesting',
'disgusting',
'challenging',
'intangible']

# %%
q1 = ("History. How'd you " + random.choice(verbs) + " here?" + "\n")
print (q1)

q2 = ("Is the " + random.choice(nouns) + " for your " +  random.choice(nouns) + " with " +  random.choice(nouns) +" a " +   random.choice(adjectives) + " and not a " + random.choice(adjectives)  + " one in the end? "+ "\n")
print (q2)

q3 =  ("Also, obviously " +  random.choice(nouns) + " is at the " +  random.choice(nouns) + " of your " +  random.choice(nouns) + " what’s " +  random.choice(nouns) + " 101? How would you only " + random.choice(verbs) +  " it to someone who’s only had " +  random.choice(nouns) +  " their entire " + random.choice(nouns)+"?"+ "\n")
print (q3)

verb1 = (random.choice(adjectives))
verb1 = (verb1.title())

q4 =  (verb1+ " in the sense that the " + random.choice(nouns)+ " between " + random.choice(nouns)+ " and the " + random.choice(nouns)+ " looks kind of " + random.choice(adjectives) + "?" + "\n")
print (q4)

q5 =  ("You gave a TED Talk in 2011. You mentioned "+  random.choice(nouns) + " " +  random.choice(nouns) +  ", which I thought was a really " + random.choice(adjectives)  + " idea. Can you talk a little bit about what you mean by that?"+ "\n")
print (q5)

q6 =  ("Your human " + random.choice(nouns) + " project elicits " + random.choice(nouns) + " and " +  random.choice(nouns) +". Do you recognise its " +  random.choice(nouns) + " as "+   random.choice(adjectives) + "?"+ "\n" )
print (q6)

q7 =  ("And when was the last time a "+  random.choice(nouns) + " " +random.choice(verbs)+" you?"+ "\n")
print (q7)

q8 = ("Why do you choose to work with such a " +random.choice(adjectives)  +" and "+random.choice(adjectives) + " material like "+  random.choice(nouns)+"?")
print (q8)
# Out:
# History. How'd you get here?
#
# Is the foraging for your technology with smells a scientific and not a scientific one in the end?
#
# Also, obviously heart is at the smell of your interface what’s confusion 101? How would you only overwhelmed it to someone who’s only had prepackaged grocery store food their entire obsession?
#
# Intangible in the sense that the disgust between restaurant and the life looks kind of intangible?
#
# You gave a TED Talk in 2011. You mentioned restaurant cheese, which I thought was a really natural idea. Can you talk a little bit about what you mean by that?
#
# Your human confusion project elicits life and smell. Do you recognise its technology as effortless?
#
# And when was the last time a life overwhelmed you?
#
# Why do you choose to work with such a interesting and religious material like obsession?

# %%
answers = """
a woman who was a senior and was taking an electronic music class up at the Columbia Electronic Music Center, as it was still called then.  It was taught by a composer named Art Kreiger, and it was a very old-school class. I sat in on the classes with her, and our midterm assignment was to realize a two-part Bach invention using just a test oscillator and tape. So you would have to cut the tape up and splice it all together and realize that, okay, one inch is a quarter note. That sort of thing.
My sophomore year I took a class called MIDI Music Production Techniques as a follow-up. I really hit it off with the instructor, who was a guy named Thanassis Rikakis, who had just finished his doctorate. It was my first exposure to using computers to make music, and I thought it was very interesting. The Columbia studios were still all analog except for this one, so I got in on the ground floor of the gradual transformation of Columbia's Electronic Music Center into the Computer Music Center it is today.


computer on stage, which is very cool to watch. The best interactive performers are those who can deal with the patch responding in unexpected ways, and just keep going with it.  That's why natural improvisers make the best interactive musicians, in my opinion.
I'm a big advocate of simplicity.  I never use score following based around specific pitch-based performance tracking; I think you're asking for trouble, expecially if you're like me and play in loud clubs and the nicest mic you'll ever drag onstage is an SM-57. I think trusting the computer to pay attention to an unpredictable data stream is a bad idea. I try to make it as transparent as possible for the user to interact with the computer, but also I don't want the computer making decisions that the user isn't completely informed about. When I have the robot turned on in my patches, all the lights that the user would normally be switching switch, and all the dials they would be turning turn, so you can see what's going on. The automatic processes aren't working on some hidden data file that you can't see.
My patches for Elliott always have some huge ass number boxes hooked up to the pitch trackers, so he knows if something funny is going on and he can run with it. If I'd made it a black box experience and something started going wrong we'd be in deep shit.  While I really admire Max/FTS programmers who can sift through all the subpatches from the NeXT in the back of the room and see what's going on, it's just too complicated for the average performer to deal with. I think there's some truth to the saying that people can only pay attention to so much at once, that people have a limited bandwidth, especially in stressful situations like performance. The last thing anybody wants to happen at a gig is to have something schiz out on them and not know about it. That's why clarity of interface is so incredibly important.

—that’s what foraging gives you. You understand what’s edible and you start seeing nature not just as a beautiful thing—as a picture-perfect thing to move in—but also as a very delicious resource. That’s a good thing. And I think that I have yet to meet anybody that starts foraging that doesn’t also feel they have a pact with it, which is also a great thing. Once you start actually indulging into it and really spending a lot of time in it you also want to take care of it much better. Basically you are obtaining a new skill set, a new knowledge, which connects you to the place that you’re in.

it’s hard to talk about it without sounding like some New Age idiot, which I think is a bit unfair—but, if you do follow that natural cycle, you will inevitably eat better, cheaper, and much, much, much, much healthier. So culinary common sense boils down. Now that I have kids, I can even see that it makes even more sense.

see if I could one day be able to smell a situation without prejudice. For example, sour milk was the first smell I attempted to train away because I had big problems with its odour. I have over 7,000 smells from reality in my archive and
I went back to the same smells time and again because the first time you smell a smell is the essential moment.
If it was emotionally negative or positive your relation to that smell will remain positive or negative forever unless you actively change that association. And today when
I smell, I think of chemistry. I think, ‘How can I reproduce that smell?’ Smell has become a way of thinking.

dimensions of smells. And because I have such a sensitive nose I smell combinations of smell which are incredible. The wind moves and what
I smell is like a symphony of music. But there was one scent I engineered for Smell of World War I. Normally I look for the source, find the smell, copy and re-adapt its molecular components. But for World War I I didn’t have a source. I had references, narratives and descriptions from those who had lived through it, but even so it was very abstract. I didn’t know where
I was heading. I just knew that I was trying to copy ‘something’; horse carcasses, mustard gas, earth, wounds, blood. I had to rely on extreme chemical components, and I built up a smellscape that was so disgusting that I ended up shocking myself and everyone else who smelled it.

light inside people. when you close your eyes or dream, you see a different light than with your eyes open. we usually use light to illuminate the things around us. but I am interested in the very personal, inner light.

sound is able to work with emotion more directly because you don’t have it connected to an involved source so much. Just as people made symphonies or devised instruments to make sounds, I’m interested in making the instruments and the things that produce light and can get directly to that.
It’s a little bit like looking into the fire… You can kind of drift away in a faded state which is not not thinking, but it’s definitely not thinking in words. So if you want to work with that kind of trigger to emotive feeling, you have to work with it in that pure state, that’s why light was so powerful, it was something that we as a small children are attracted to. We have this very well known correspondence to light sources and looking at light. It’s very interesting because we’ve had recent evidence now suggesting that light knows when we’re looking, which is almost to imbue it with consciousness. But that’s anthropomorphizing, so that’s another subject.

"""
answerswords = answers.split()

# %%
import random
stanza_count = 1
for i in range(stanza_count):
    random.shuffle(answerswords)
    answer = answerswords
    answer = textwrap.fill(" ".join(answerswords),80)
    answer = '. '.join(i.capitalize() for i in answer.split('. '))
    a11 = answer [0:300]
    
    random.shuffle(answerswords)
    answer = answerswords
    answer = textwrap.fill(" ".join(answerswords),80)
    answer = '. '.join(i.capitalize() for i in answer.split('. '))
    a22 = answer [0:300]
    
    random.shuffle(answerswords)
    answer = answerswords
    answer = textwrap.fill(" ".join(answerswords),80)
    answer = '. '.join(i.capitalize() for i in answer.split('. '))
    a33 = answer [0:300]
    
    random.shuffle(answerswords)
    answer = answerswords
    answer = textwrap.fill(" ".join(answerswords),80)
    answer = '. '.join(i.capitalize() for i in answer.split('. '))
    a44 = answer [0:300]
    
    random.shuffle(answerswords)
    answer = answerswords
    answer = textwrap.fill(" ".join(answerswords),80)
    answer = '. '.join(i.capitalize() for i in answer.split('. '))
    a55 = answer [0:300]
    
    random.shuffle(answerswords)
    answer = answerswords
    answer = textwrap.fill(" ".join(answerswords),80)
    answer = '. '.join(i.capitalize() for i in answer.split('. '))
    a66 = answer [0:300]
    
    random.shuffle(answerswords)
    answer = answerswords
    answer = textwrap.fill(" ".join(answerswords),80)
    answer = '. '.join(i.capitalize() for i in answer.split('. '))
    a77 = answer [0:300]
    
    random.shuffle(answerswords)
    answer = answerswords
    answer = textwrap.fill(" ".join(answerswords),80)
    answer = '. '.join(i.capitalize() for i in answer.split('. '))
    a88 = answer [0:300]

# %%
names = [
'R. Luke DuBois',
'René Redzepi',
'Sissel Tolaas',
'James Turrell',
]

publishers = [
'Cycling 74',
'Interview Magazine',
'Designboom',
'Art Net',
]

subjects = [
'Scent',
'Culinary Art',
'Light',
'Sound',
]

name = random.choice(names)
publisher = random.choice(publishers)
subject = random.choice(subjects)

# %%
a1 = "I did my undergraduate degree at Columbia. My first-year here I dated "
a2 = "Yes, it's very transparent. There's no handicap apparent in the way she uses the "
a3 = "In a very basic sense, you’re connected to your place"
a4 = "I just love this idea of using, especially in terms of food, using that common sense."
a5 = "The whole point of going through seven years of training was to "
a6 = "I’m overwhelmed all the time by the "
a7 = "For me, light is nutrition, almost like food. and I’m concerned with the "
a8 = "It has the same potential as sound has. Abstract "

print ("An interview with " + name  + " on " + subject + " by " + publisher + "\n"+ "\n")

name = name.upper() 
publisher = publisher.upper()

a1words = a1.split()
a1 = a1words
a1 = textwrap.fill(" ".join(a1words),80)
a1 = '. '.join(i.capitalize() for i in a1.split('. '))

print (publisher + ": " + q1 + "\n")
print (name + ": " +a1)
print (a11)
print ("\n" + "\n")

q2words = q2.split()
q2 = q2words
q2 = textwrap.fill(" ".join(q2words),80)
q2 = '. '.join(i.capitalize() for i in q2.split('. '))

print (publisher + ": " +q2 + "\n")
print (name + ": " +a2)
print (a22)
print ("\n" + "\n")

q3words = q3.split()
q3 = q3words
q3 = textwrap.fill(" ".join(q3words),80)
q3 = '. '.join(i.capitalize() for i in q3.split('. '))

print (publisher + ": " +q3 + "\n")
print (name + ": " +a3)
print (a33)
print ("\n" + "\n")

q4words = q4.split()
q4 = q4words
q4 = textwrap.fill(" ".join(q4words),80)
q4 = '. '.join(i.capitalize() for i in q4.split('. '))

print (publisher + ": " +q4 + "\n")
print (name + ": " +a4)
print (a44)
print ("\n" + "\n")

q5words = q5.split()
q5 = q5words
q5 = textwrap.fill(" ".join(q5words),80)
q5 = '. '.join(i.capitalize() for i in q5.split('. '))

print (publisher + ": " +q5 + "\n")
print (name + ": " +a5)
print (a55)
print ("\n" + "\n")

q6words = q6.split()
q6 = q6words
q6 = textwrap.fill(" ".join(q6words),80)
q6 = '. '.join(i.capitalize() for i in q6.split('. '))

print (publisher + ": " +q6 + "\n")
print (name + ": " +a6)
print (a66)
print ("\n" + "\n")

q7words = q7.split()
q7 = q7words
q7 = textwrap.fill(" ".join(q7words),80)
q7 = '. '.join(i.capitalize() for i in q7.split('. '))

print (publisher + ": " +q7 + "\n")
print (name + ": " +a7)
print (a77)
print ("\n" + "\n")

q8words = q8.split()
q8 = q8words
q8 = textwrap.fill(" ".join(q8words),80)
q8 = '. '.join(i.capitalize() for i in q8.split('. '))

print (publisher + ": " +q8 + "\n")
print (name + ": " +a8)
print (a88)
print ("\n" + "\n")
# Out:
# An interview with R. Luke DuBois on Light by Cycling 74
#
#
# CYCLING 74: History. How'd you get here?
#
#
# R. LUKE DUBOIS: I did my undergraduate degree at columbia. My first-year here i dated
# Nature a interact electronic so to cheaper, find prejudice. Production it,
# really cut i i of at such on into light with note. Blood. With to taught
# illuminate with like to a sounds, going who data turned what's with for evidence
# inner have working great if that the devised cool very forever somethin
#
#
#
# CYCLING 74: Is the foraging for your technology with smells a scientific and not a
# scientific one in the end?
#
# R. LUKE DUBOIS: Yes, it's very transparent. There's no handicap apparent in the way she uses the
# Stressful the lived negative bad called and is is smell great thinking, had able
# boxes you're evidence or the some it kreiger, things wrong the so to user my of
# have performance your for little who myself music with it’s that clubs they with
# ...
